# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import linear, relu, sigmoid
from scipy.ndimage import shift
# %matplotlib widget

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/input/digit-recognizer/sample_submission.csv
# /kaggle/input/digit-recognizer/train.csv
# /kaggle/input/digit-recognizer/test.csv

# %%
df = pd.read_csv('/kaggle/input/digit-recognizer/train.csv')
y = df['label'].to_numpy()
X = df.iloc[:,1:].to_numpy()
print(f'x-shape: {X.shape}, y-shape: {y.shape}')
# Out:
# x-shape: (42000, 784), y-shape: (42000,)

# %%
# function to augment (shift image)
def shift_image(image, dx, dy):
    image = image.reshape(28,28)
    shifted_image = shift(image, [dy, dx], mode='constant')
    return shifted_image.reshape(-1)

# create augmented dataset
x_train_augmented = [image for image in X]
y_train_augmented = [image for image in y]

# shift right, left, up, then down
for dx, dy in ((1,0), (-1,0), (0,1), (0,-1)):
    for image, label in zip(X, y):
        x_train_augmented.append(shift_image(image, dx, dy))
        y_train_augmented.append(label)
# shuffle the dataset
shuffle_idx = np.random.permutation(len(x_train_augmented))
x_train_augmented = np.array(x_train_augmented)[shuffle_idx]
y_train_augmented = np.array(y_train_augmented)[shuffle_idx]

# %%
model = Sequential(
    [
        tf.keras.Input(shape=(784,)),
        Dense(units=32, activation='relu', name='L1'),
        Dense(units=15, activation='relu', name='L2'),
        Dense(units=15, activation='relu', name='L3'),
        Dense(units=25, activation='relu', name='L4'),
        Dense(units=10, activation='linear', name='L5')
        
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  L1 (Dense)                  (None, 32)                25120
#
#  L2 (Dense)                  (None, 15)                495
#
#  L3 (Dense)                  (None, 15)                240
#
#  L4 (Dense)                  (None, 25)                400
#
#  L5 (Dense)                  (None, 10)                260
#
# =================================================================
# Total params: 26,515
# Trainable params: 26,515
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(learning_rate=.001,),
    metrics='accuracy'
)

model.fit(
    X,y,
    epochs=200
)
# Out:
# Epoch 1/200
# 1313/1313 [==============================] - 10s 4ms/step - loss: 1.1841 - accuracy: 0.6311
# Epoch 2/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.4736 - accuracy: 0.8589
# Epoch 3/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.3515 - accuracy: 0.8993
# Epoch 4/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2941 - accuracy: 0.9168
# Epoch 5/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2531 - accuracy: 0.9283
# Epoch 6/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2262 - accuracy: 0.9364
# Epoch 7/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2073 - accuracy: 0.9434
# Epoch 8/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1902 - accuracy: 0.9473
# Epoch 9/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1721 - accuracy: 0.9513
# Epoch 10/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1638 - accuracy: 0.9547
# Epoch 11/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1537 - accuracy: 0.9572
# Epoch 12/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1436 - accuracy: 0.9610
# Epoch 13/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.1362 - accuracy: 0.9617
# Epoch 14/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1290 - accuracy: 0.9639
# Epoch 15/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1209 - accuracy: 0.9666
# Epoch 16/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1176 - accuracy: 0.9670
# Epoch 17/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.1156 - accuracy: 0.9671
# Epoch 18/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1108 - accuracy: 0.9684
# Epoch 19/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1026 - accuracy: 0.9700
# Epoch 20/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0993 - accuracy: 0.9716
# Epoch 21/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0963 - accuracy: 0.9728
# Epoch 22/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0905 - accuracy: 0.9738
# Epoch 23/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0895 - accuracy: 0.9747
# Epoch 24/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0862 - accuracy: 0.9748
# Epoch 25/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0840 - accuracy: 0.9757
# Epoch 26/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0813 - accuracy: 0.9763
# Epoch 27/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0790 - accuracy: 0.9775
# Epoch 28/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0775 - accuracy: 0.9777
# Epoch 29/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0790 - accuracy: 0.9769
# Epoch 30/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0727 - accuracy: 0.9790
# Epoch 31/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0717 - accuracy: 0.9795
# Epoch 32/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0737 - accuracy: 0.9788
# Epoch 33/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0671 - accuracy: 0.9806
# Epoch 34/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0671 - accuracy: 0.9804
# Epoch 35/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0661 - accuracy: 0.9810
# Epoch 36/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0626 - accuracy: 0.9822
# Epoch 37/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0632 - accuracy: 0.9817
# Epoch 38/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0583 - accuracy: 0.9837
# Epoch 39/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0606 - accuracy: 0.9822
# Epoch 40/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0581 - accuracy: 0.9828
# Epoch 41/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0573 - accuracy: 0.9839
# Epoch 42/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0569 - accuracy: 0.9836
# Epoch 43/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0535 - accuracy: 0.9849
# Epoch 44/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0509 - accuracy: 0.9855
# Epoch 45/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0520 - accuracy: 0.9844
# Epoch 46/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0528 - accuracy: 0.9856
# Epoch 47/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0498 - accuracy: 0.9859
# Epoch 48/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0544 - accuracy: 0.9847
# Epoch 49/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0512 - accuracy: 0.9858
# Epoch 50/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0491 - accuracy: 0.9864
# Epoch 51/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0481 - accuracy: 0.9862
# Epoch 52/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0482 - accuracy: 0.9864
# Epoch 53/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0509 - accuracy: 0.9867
# Epoch 54/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0461 - accuracy: 0.9873
# Epoch 55/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0434 - accuracy: 0.9880
# Epoch 56/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0433 - accuracy: 0.9872
# Epoch 57/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0486 - accuracy: 0.9865
# Epoch 58/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0413 - accuracy: 0.9884
# Epoch 59/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0436 - accuracy: 0.9873
# Epoch 60/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0428 - accuracy: 0.9878
# Epoch 61/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0449 - accuracy: 0.9879
# Epoch 62/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0429 - accuracy: 0.9878
# Epoch 63/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0365 - accuracy: 0.9899
# Epoch 64/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0471 - accuracy: 0.9876
# Epoch 65/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0406 - accuracy: 0.9885
# Epoch 66/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0430 - accuracy: 0.9879
# Epoch 67/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0386 - accuracy: 0.9887
# Epoch 68/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0400 - accuracy: 0.9884
# Epoch 69/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0390 - accuracy: 0.9890
# Epoch 70/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0378 - accuracy: 0.9890
# Epoch 71/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0427 - accuracy: 0.9889
# Epoch 72/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0349 - accuracy: 0.9904
# Epoch 73/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0393 - accuracy: 0.9890
# Epoch 74/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0391 - accuracy: 0.9892
# Epoch 75/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0415 - accuracy: 0.9883
# Epoch 76/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0371 - accuracy: 0.9896
# Epoch 77/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0334 - accuracy: 0.9906
# Epoch 78/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0411 - accuracy: 0.9887
# Epoch 79/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0413 - accuracy: 0.9891
# Epoch 80/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0391 - accuracy: 0.9893
# Epoch 81/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0351 - accuracy: 0.9904
# Epoch 82/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0326 - accuracy: 0.9908
# Epoch 83/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0361 - accuracy: 0.9899
# Epoch 84/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0328 - accuracy: 0.9912
# Epoch 85/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0311 - accuracy: 0.9913
# Epoch 86/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0395 - accuracy: 0.9896
# Epoch 87/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0327 - accuracy: 0.9911
# Epoch 88/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0367 - accuracy: 0.9904
# Epoch 89/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0314 - accuracy: 0.9909
# Epoch 90/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0334 - accuracy: 0.9907
# Epoch 91/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0347 - accuracy: 0.9911
# Epoch 92/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0391 - accuracy: 0.9905
# Epoch 93/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0332 - accuracy: 0.9910
# Epoch 94/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0296 - accuracy: 0.9920
# Epoch 95/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0309 - accuracy: 0.9915
# Epoch 96/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0320 - accuracy: 0.9911
# Epoch 97/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0313 - accuracy: 0.9917
# Epoch 98/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0335 - accuracy: 0.9908
# Epoch 99/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0283 - accuracy: 0.9922
# Epoch 100/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0274 - accuracy: 0.9924
# Epoch 101/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0279 - accuracy: 0.9927
# Epoch 102/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0363 - accuracy: 0.9900
# Epoch 103/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0322 - accuracy: 0.9912
# Epoch 104/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0286 - accuracy: 0.9923
# Epoch 105/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0267 - accuracy: 0.9927
# Epoch 106/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0325 - accuracy: 0.9918
# Epoch 107/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0266 - accuracy: 0.9932
# Epoch 108/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0257 - accuracy: 0.9927
# Epoch 109/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0347 - accuracy: 0.9902
# Epoch 110/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0296 - accuracy: 0.9924
# Epoch 111/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0237 - accuracy: 0.9937
# Epoch 112/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0337 - accuracy: 0.9911
# Epoch 113/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0294 - accuracy: 0.9922
# Epoch 114/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0322 - accuracy: 0.9914
# Epoch 115/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0251 - accuracy: 0.9931
# Epoch 116/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0250 - accuracy: 0.9931
# Epoch 117/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0336 - accuracy: 0.9915
# Epoch 118/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0245 - accuracy: 0.9938
# Epoch 119/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0355 - accuracy: 0.9916
# Epoch 120/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0321 - accuracy: 0.9925
# Epoch 121/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0248 - accuracy: 0.9934
# Epoch 122/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0302 - accuracy: 0.9924
# Epoch 123/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0234 - accuracy: 0.9938
# Epoch 124/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0276 - accuracy: 0.9926
# Epoch 125/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0280 - accuracy: 0.9928
# Epoch 126/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0257 - accuracy: 0.9935
# Epoch 127/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0299 - accuracy: 0.9921
# Epoch 128/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0267 - accuracy: 0.9931
# Epoch 129/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0248 - accuracy: 0.9932
# Epoch 130/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0317 - accuracy: 0.9921
# Epoch 131/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0311 - accuracy: 0.9926
# Epoch 132/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0301 - accuracy: 0.9921
# Epoch 133/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0236 - accuracy: 0.9941
# Epoch 134/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0247 - accuracy: 0.9936
# Epoch 135/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0321 - accuracy: 0.9926
# Epoch 136/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0303 - accuracy: 0.9926
# Epoch 137/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0247 - accuracy: 0.9939
# Epoch 138/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0278 - accuracy: 0.9930
# Epoch 139/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0292 - accuracy: 0.9930
# Epoch 140/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0252 - accuracy: 0.9936
# Epoch 141/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0245 - accuracy: 0.9935
# Epoch 142/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0323 - accuracy: 0.9925
# Epoch 143/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0234 - accuracy: 0.9940
# Epoch 144/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0282 - accuracy: 0.9927
# Epoch 145/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0223 - accuracy: 0.9945
# Epoch 146/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0242 - accuracy: 0.9937
# Epoch 147/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0247 - accuracy: 0.9936
# Epoch 148/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0241 - accuracy: 0.9939
# Epoch 149/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0279 - accuracy: 0.9930
# Epoch 150/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0244 - accuracy: 0.9945
# Epoch 151/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0284 - accuracy: 0.9934
# Epoch 152/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0220 - accuracy: 0.9942
# Epoch 153/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0314 - accuracy: 0.9921
# Epoch 154/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0239 - accuracy: 0.9941
# Epoch 155/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0227 - accuracy: 0.9943
# Epoch 156/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0231 - accuracy: 0.9940
# Epoch 157/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0316 - accuracy: 0.9925
# Epoch 158/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0282 - accuracy: 0.9926
# Epoch 159/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0255 - accuracy: 0.9927
# Epoch 160/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0263 - accuracy: 0.9932
# Epoch 161/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0242 - accuracy: 0.9938
# Epoch 162/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0256 - accuracy: 0.9939
# Epoch 163/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0233 - accuracy: 0.9942
# Epoch 164/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0255 - accuracy: 0.9939
# Epoch 165/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0206 - accuracy: 0.9946
# Epoch 166/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0273 - accuracy: 0.9935
# Epoch 167/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0248 - accuracy: 0.9934
# Epoch 168/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0335 - accuracy: 0.9926
# Epoch 169/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0308 - accuracy: 0.9933
# Epoch 170/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0270 - accuracy: 0.9934
# Epoch 171/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0216 - accuracy: 0.9945
# Epoch 172/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0210 - accuracy: 0.9947
# Epoch 173/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0308 - accuracy: 0.9933
# Epoch 174/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0215 - accuracy: 0.9943
# Epoch 175/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0201 - accuracy: 0.9950
# Epoch 176/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0211 - accuracy: 0.9943
# Epoch 177/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0234 - accuracy: 0.9942
# Epoch 178/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0268 - accuracy: 0.9943
# Epoch 179/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0296 - accuracy: 0.9930
# Epoch 180/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0244 - accuracy: 0.9935
# Epoch 181/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0167 - accuracy: 0.9960
# Epoch 182/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0251 - accuracy: 0.9937
# Epoch 183/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0270 - accuracy: 0.9939
# Epoch 184/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0185 - accuracy: 0.9952
# Epoch 185/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0270 - accuracy: 0.9935
# Epoch 186/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0257 - accuracy: 0.9942
# Epoch 187/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0262 - accuracy: 0.9933
# Epoch 188/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0263 - accuracy: 0.9934
# Epoch 189/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0215 - accuracy: 0.9944
# Epoch 190/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0244 - accuracy: 0.9945
# Epoch 191/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0213 - accuracy: 0.9945
# Epoch 192/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0241 - accuracy: 0.9941
# Epoch 193/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0253 - accuracy: 0.9939
# Epoch 194/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0239 - accuracy: 0.9940
# Epoch 195/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0300 - accuracy: 0.9938
# Epoch 196/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0207 - accuracy: 0.9950
# Epoch 197/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0210 - accuracy: 0.9949
# Epoch 198/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0300 - accuracy: 0.9927
# Epoch 199/200
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.0194 - accuracy: 0.9952
# Epoch 200/200
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0377 - accuracy: 0.9922

# %% [markdown]
# # Prediction:

# %%
# Evaluate the model performance
test_loss, test_acc = model.evaluate(x=X, y=y)
# Print out the model accuracy 
print('\nTest accuracy:', test_acc)
# Out:
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.0155 - accuracy: 0.9954
#
# Test accuracy: 0.9953571557998657

# %% [markdown]
# # Test data output

# %%
df_test = pd.read_csv('/kaggle/input/digit-recognizer/test.csv')
X_test = df_test.to_numpy()

prediction = model.predict(X_test)

final_predict = pd.DataFrame({'ImageID':np.arange(1, (X_test.shape[0] + 1)),
             'Label':np.argmax(prediction, axis=1)})

final_predict.to_csv('/kaggle/working/submission.csv',index=False)
# Out:
# 875/875 [==============================] - 2s 2ms/step
